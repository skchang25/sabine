# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import pandas as pd

# %%
df = pd.read_csv("astro_image.csv")
image = df.values
#with fits.open("astro_image.csv") as hdul:
    #header = hdul[0].header
    #print(header)
    #data = hdul[0].data
    #print(data)
