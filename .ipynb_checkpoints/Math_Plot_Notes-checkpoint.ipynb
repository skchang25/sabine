# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.loadtxt("astro_image.csv")

# %%
im
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          1.08835139e-27, -8.33020372e-29,  2.16325398e-30],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -6.11796082e-29, -1.23338997e-28, -8.22500920e-31],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.66116853e-27, -8.36980746e-28, -4.93603477e-29],
#        ...,
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00]])

# %%
im[0]
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         1.08835139e-27, -8.33020372e-29,  2.16325398e-30])

# %%
plt.figure()
plt.imshow(im, vmin=50, vmax = 400, cmap = 'inferno')
plt.colorbar()
plt.show()
