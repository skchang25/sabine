# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("exoplanet_data.csv",comment = "#")
pd.read_csv("exoplanet_data.csv",comment = "#")
# Out:
#          pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0        7 CMa c      7 CMa             1        1        2  Radial Velocity
# 1        7 CMa c      7 CMa             0        1        2  Radial Velocity
# 2       DMPP-1 b     DMPP-1             1        1        4  Radial Velocity
# 3       DMPP-1 c     DMPP-1             1        1        4  Radial Velocity
# 4       DMPP-1 d     DMPP-1             1        1        4  Radial Velocity
# ..           ...        ...           ...      ...      ...              ...
# 562    bet Pic c    bet Pic             1        1        2  Radial Velocity
# 563    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 564    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 565  eps Ind A b  eps Ind A             0        3        1  Radial Velocity
# 566  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
#
#      disc_year           disc_facility              soltype  pl_controv_flag  \
# 0         2019  Multiple Observatories  Published Confirmed                0
# 1         2019  Multiple Observatories  Published Confirmed                0
# 2         2019    La Silla Observatory  Published Confirmed                0
# 3         2019    La Silla Observatory  Published Confirmed                0
# 4         2019    La Silla Observatory  Published Confirmed                0
# ..         ...                     ...                  ...              ...
# 562       2019    La Silla Observatory  Published Confirmed                0
# 563       2019    La Silla Observatory  Published Confirmed                0
# 564       2019    La Silla Observatory  Published Confirmed                0
# 565       2019    La Silla Observatory  Published Confirmed                0
# 566       2019    La Silla Observatory  Published Confirmed                0
#
#      ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  \
# 0    ...       -0.03    1.564        0.252       -0.252     3.67853
# 1    ...       -0.03    1.564        0.252       -0.252     3.67853
# 2    ...       -0.03    6.690        0.024       -0.024     7.85032
# 3    ...       -0.03    6.690        0.024       -0.024     7.85032
# 4    ...       -0.03    6.690        0.024       -0.024     7.85032
# ..   ...         ...      ...          ...          ...         ...
# 562  ...       -0.03    3.526        0.222       -0.222     3.82015
# 563  ...       -0.03    3.526        0.222       -0.222     3.82015
# 564  ...       -0.03    3.526        0.222       -0.222     3.82015
# 565  ...       -0.03    2.237        0.240       -0.240     4.34562
# 566  ...       -0.03    2.237        0.240       -0.240     4.34562
#
#      sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate
# 0          0.004135       -0.004135  2019-10-18     2019-11   2019-10-24
# 1          0.004135       -0.004135  2024-09-13     2024-07   2024-09-13
# 2          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# 3          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# 4          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# ..              ...             ...         ...         ...          ...
# 562        0.004427       -0.004427  2023-06-12     2022-09   2023-06-12
# 563        0.004427       -0.004427  2025-09-25     2020-10   2025-09-25
# 564        0.004427       -0.004427  2019-08-23     2019-08   2019-08-29
# 565        0.007374       -0.007374  2019-10-18     2019-12   2019-10-24
# 566        0.007374       -0.007374  2024-08-07     2024-09   2024-08-07
#
# [567 rows x 92 columns]

# %%
print(data.shape) # 567 rows, 92 columns
print(data.columns) # pl_orbperlim, pl_bmasseerr2, decstr, st_tefflim, sy_gaiamag
# Planet name --> pl_name†, planet name used most commonly.
# Host name --> hostname†, stellar name used commonly.
# Discovery method --> discoverymethod†, The method used to first identiy the planet
# Spectral type --> st_spectype, Classifying stars based on their spectral characteristics.
# Equalibrium temerpature --> pl_eqt†, the effective temperature for a planet that absorbs heat from its system or to match its luminoscity if it where able to absorb energy ideally (black body).
# Planet Mass --> pl_massj (jupiter), amount of matter contained in the planet measured in jupiters 

data_col = pd.DataFrame(data[["pl_name","hostname","discoverymethod","st_spectype","pl_eqt","pl_bmassj"]])
data_col = data_col.dropna()
print(data_col.shape) # 67 rows, 6 columns
print(f"Head: {data_col.head()}")
print(f"Tail: {data_col.tail()}")
print(data_col.columns)
# Out:
# (567, 92)
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
#        'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_masslim', 'st_met', 'st_meterr1', 'st_meterr2', 'st_metlim',
#        'st_metratio', 'st_logg', 'st_loggerr1', 'st_loggerr2', 'st_logglim',
#        'sy_refname', 'rastr', 'ra', 'decstr', 'dec', 'sy_dist', 'sy_disterr1',
#        'sy_disterr2', 'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmag',
#        'sy_kmagerr1', 'sy_kmagerr2', 'sy_gaiamag', 'sy_gaiamagerr1',
#        'sy_gaiamagerr2', 'rowupdate', 'pl_pubdate', 'releasedate'],
#       dtype='object')
# (67, 6)
# Head:     pl_name hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 2  DMPP-1 b   DMPP-1  Radial Velocity        F8 V   877.0   0.076362
# 3  DMPP-1 c   DMPP-1  Radial Velocity        F8 V  1239.0   0.030205
# 4  DMPP-1 d   DMPP-1  Radial Velocity        F8 V  1632.0   0.010540
# 5  DMPP-1 e   DMPP-1  Radial Velocity        F8 V  1314.0   0.012994
# 6  DMPP-2 b   DMPP-2  Radial Velocity        F5 V  1000.0   0.437000
# Tail:          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 546   WASP-185 b   WASP-185          Transit        G0 V  1160.0      0.980
# 549   WASP-190 b   WASP-190          Transit     F6 IV-V  1500.0      1.000
# 555   WASP-192 b   WASP-192          Transit        G0 V  1620.0      2.300
# 561       XO-7 b       XO-7          Transit        G0 V  1743.0      0.709
# 566  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0      6.310
# Index(['pl_name', 'hostname', 'discoverymethod', 'st_spectype', 'pl_eqt',
#        'pl_bmassj'],
#       dtype='object')

# %%
print(data_col["discoverymethod"].value_counts())
# Discovery methods include: Transit (52), Radial Velocity (13) and Imaging (2).
# Transit is repersented the most: Observing when a light dip occurs due to path taken where the exoplanet passes between us and a star
# Radial velocity: Observign the changes in a star's motion in orbit of a planet effecting the light it gives off
# Imaging if the least repersented in the data: oberving imaging of the exoplanet.
# Out:
# discoverymethod
# Transit            52
# Radial Velocity    13
# Imaging             2
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(data = data_col, x= 'pl_bmassj', y = 'pl_eqt', hue = 'discoverymethod')
plt.title("Planet Mass versus Equalibrium temperature")
plt.xlabel("Planet Mass (Jupiters)")
plt.ylabel("Equalibrium temperature (Kelvin)")
plt.show()

# %%
plt.figure(figsize = (8,6))
x = np.log(data_col["pl_bmassj"])
y = np.log(data_col["pl_eqt"])
df_removed = data_col.drop(['pl_bmassj', 'pl_eqt'], axis=1)
df_removed["pl_bmassj"] = x
df_removed["pl_eqt"] = y
sns.scatterplot(data = df_removed, x= 'pl_bmassj', y = 'pl_eqt', hue = 'discoverymethod')
plt.title("Logarithmic plot: Planet Mass versus Equalibrium temperature")
plt.xlabel("Planet Mass (log(Jupiters))")
plt.ylabel("Equalibrium temperature (log(Kelvin))")
plt.show()
# The planets found by imaging are found to have relatively more mass than other observed planets.

# %%
mask = data_col["pl_bmassj"] > 5
over_five = data_col[mask]
print(over_five["pl_eqt"].min())
coldest = over_five["pl_eqt"] == 275.0
coldest_planet = over_five[coldest]
coldest_planet = coldest_planet.dropna()
print(coldest_planet)

# name = eps Ind A b, index = 566, temp = 275.0, mass = 6.31 jupiters, orbits a similar star to our sun (K5 V) a main sequency star.
# Out:
# 275.0
#          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 566  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0       6.31

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(data = df_removed, x= 'pl_bmassj', y = 'pl_eqt', hue = 'discoverymethod')
plt.scatter( np.log(over_five["pl_bmassj"]),np.log(over_five["pl_eqt"]), c = "red", s = 40, label = "Coldest planets")
plt.title("Logarithmic plot: Planet Mass versus Equalibrium temperature")
plt.xlabel("Planet Mass (log(Jupiters))")
plt.ylabel("Equalibrium temperature (log(Kelvin))")
plt.legend()
plt.show()

# %%
# A temperate super-Jupiter imaged with JWST  in the mid-infared.
# Previous data of planet behvaior is challenged by the new data rvealing termperatures around 275K are brighter than preivously thought, leading to questions on the opacisty and carbon to oxygen ration on the planets. By studying stars aged 500 Myr and younger, we are able to establish that larger planets exist in the system which challenges there known orbital properties.
# As the paper states the warmer planets should exhibit more brightness and arae consistent with larger body systems, we can match this finding to our data.
